# %% [markdown]
# <a href="https://colab.research.google.com/github/9192gks/CreateMlModel/blob/main/Turicreate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install tensorflow-gpu
# Out:
# ...
#      |████████████████████████████████| 394.3MB 43kB/s
# ...
#      |████████████████████████████████| 471kB 53.1MB/s
# ...
#      |████████████████████████████████| 10.6MB 48.3MB/s
# ...
# ERROR: tensorflow 2.0.4 has requirement gast==0.2.2, but you'll have gast 0.3.3 which is incompatible.
# ERROR: tensorflow 2.0.4 has requirement numpy<1.19.0,>=1.16.0, but you'll have numpy 1.19.5 which is incompatible.
# ERROR: tensorflow 2.0.4 has requirement tensorboard<2.1.0,>=2.0.0, but you'll have tensorboard 2.4.1 which is incompatible.
# ERROR: tensorflow 2.0.4 has requirement tensorflow-estimator<2.1.0,>=2.0.0, but you'll have tensorflow-estimator 2.4.0 which is incompatible.
# ...
#   Found existing installation: tensorflow-estimator 2.0.1
#     Uninstalling tensorflow-estimator-2.0.1:
#       Successfully uninstalled tensorflow-estimator-2.0.1
#   Found existing installation: gast 0.2.2
#     Uninstalling gast-0.2.2:
#       Successfully uninstalled gast-0.2.2
# ...

# %%
# !pip install -U turicreate
# Out:
# Requirement already up-to-date: turicreate in /usr/local/lib/python3.7/dist-packages (6.4.1)
# ...
# Processing /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd/gast-0.2.2-cp37-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/fc/08/8b927337b7019c374719145d1dceba21a8bb909b93b1ad6f8fb7d22c1ca1/tensorflow_estimator-2.0.1-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/76/54/99b9d5d52d5cb732f099baaaf7740403e83fe6b0cedde940fabd2b13d75a/tensorboard-2.0.2-py3-none-any.whl
# ...
# ERROR: tensorflow 2.0.4 has requirement numpy<1.19.0,>=1.16.0, but you'll have numpy 1.19.5 which is incompatible.
# ERROR: tensorflow-probability 0.12.1 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# ERROR: tensorflow-gpu 2.4.1 has requirement gast==0.3.3, but you'll have gast 0.2.2 which is incompatible.
# ...

# %%
# %cd drive/MyDrive/vision/
# Out:
# /content/drive/MyDrive/vision

# %%
# !python prep.py out.csv
# Out:
# label = item[path]
#  /content/drive/MyDrive/vision/images/1209.jpg
# label is 1209.jpg
# label = item[path]
#  /content/drive/MyDrive/vision/images/1210.jpg
# label is 1210.jpg
# label = item[path]
#  /content/drive/MyDrive/vision/images/1212.jpg
# label is 1212.jpg
# label = item[path]
#  /content/drive/MyDrive/vision/images/1213.jpg
# label is 1213.jpg
# label = item[path]
#  /content/drive/MyDrive/vision/images/1214.jpg
# label is 1214.jpg
# label = item[path]
#  /content/drive/MyDrive/vision/images/1216.jpg
# label is 1216.jpg
# label = item[path]
#  /content/drive/MyDrive/vision/images/1217.jpg
# label is 1217.jpg
# label = item[path]
#  /content/drive/MyDrive/vision/images/1224.jpg
# label is 1224.jpg
# label = item[path]
#  /content/drive/MyDrive/vision/images/1227.jpg
# label is 1227.jpg
# label = item[path]
#  /content/drive/MyDrive/vision/images/1228.jpg
# label is 1228.jpg
# label = item[path]
#  /content/drive/MyDrive/vision/images/1230.jpg
# label is 1230.jpg
# ...

# %%
# !python train.py
# Out:
# Using a GPU to create model.
# Setting 'batch_size' to 32
# +--------------+--------------+--------------+
# | Iteration    | Loss         | Elapsed Time |
# +--------------+--------------+--------------+
# | 1            | 57.7302      | 43.95s       |
# | 2            | 57.7363      | 46.25s       |
# | 3            | 57.6207      | 48.63s       |
# | 4            | 57.5033      | 51.08s       |
# | 5            | 57.2751      | 53.43s       |
# | 10           | 54.31        | 1m 4s        |
# | 15           | 48.8077      | 1m 14s       |
# | 20           | 41.573       | 1m 25s       |
# | 25           | 33.8623      | 1m 36s       |
# | 30           | 26.6539      | 1m 47s       |
# | 35           | 20.5495      | 1m 58s       |
# | 40           | 15.5603      | 2m 8s        |
# | 45           | 11.7285      | 2m 19s       |
# | 50           | 8.97824      | 2m 30s       |
# | 55           | 7.10417      | 2m 41s       |
# | 60           | 5.81418      | 2m 51s       |
# ...
